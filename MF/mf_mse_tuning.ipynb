# %%
from utils.evaluator.evaluator import evaluator
from utils.submission_helper import submission_helper
from utils.data_manager.data_manager import data_manager
from utils.data_manager.splitter import splitter
import matplotlib.pyplot as plt
import numpy as np
import pandas as pd
from MF.MF_mse_recommender import MF_mse_recommender

# %%
training, validation, test = splitter().get_train_evaluation_test(percentage_of_training_data=0.6,
                                                                  percentage_of_validation_data=0.2)

# %%
num_factors = [n for n in range(50, 1050, 100)]
epochs = [e for e in range(10,150, 20)]
map_vector = []
for n in num_factors:
    for e in epochs:
        recommender = MF_mse_recommender()
        recommender.fit(training_set = training.copy(),
                        epochs=e,
                        batch_size=150,
                        num_factors=n,
                        learning_rate=0.0001,
                        use_cuda=False)
        map_ = evaluator.evaluate_already_trained(recommender=recommender)[2]
        print("\n\n\n", map_, "\n\n\n")
        map_vector.append(map_)
map_vector
# Out:
# MF_MSE_PyTorch_Recommender: URM Detected 461 (5.80 %) cold users.
# MF_MSE_PyTorch_Recommender: URM Detected 5495 (21.15 %) cold items.
# MF_MSE_PyTorch_Recommender: MF_MSE_PyTorch: Using CPU
# MF_MSE_PyTorch_Recommender: Epoch 1, Batch: [403/403], Samples per second 10326.28
# MF_MSE_PyTorch_Recommender: Epoch 1 of 10. Elapsed time 5.87 sec
# MF_MSE_PyTorch_Recommender: Epoch 2, Batch: [403/403], Samples per second 10852.79
# MF_MSE_PyTorch_Recommender: Epoch 2 of 10. Elapsed time 11.46 sec
# MF_MSE_PyTorch_Recommender: Epoch 3, Batch: [403/403], Samples per second 10909.59
# MF_MSE_PyTorch_Recommender: Epoch 3 of 10. Elapsed time 17.01 sec
# MF_MSE_PyTorch_Recommender: Epoch 4, Batch: [403/403], Samples per second 11140.80
# MF_MSE_PyTorch_Recommender: Epoch 4 of 10. Elapsed time 22.46 sec
# MF_MSE_PyTorch_Recommender: Epoch 5, Batch: [403/403], Samples per second 10846.94
# MF_MSE_PyTorch_Recommender: Epoch 5 of 10. Elapsed time 28.05 sec
# MF_MSE_PyTorch_Recommender: Epoch 6, Batch: [403/403], Samples per second 10953.07
# MF_MSE_PyTorch_Recommender: Epoch 6 of 10. Elapsed time 33.59 sec
# MF_MSE_PyTorch_Recommender: Epoch 7, Batch: [403/403], Samples per second 11029.01
# MF_MSE_PyTorch_Recommender: Epoch 7 of 10. Elapsed time 39.10 sec
# MF_MSE_PyTorch_Recommender: Epoch 8, Batch: [403/403], Samples per second 11412.13
# MF_MSE_PyTorch_Recommender: Epoch 8 of 10. Elapsed time 44.41 sec
# MF_MSE_PyTorch_Recommender: Epoch 9, Batch: [403/403], Samples per second 10291.12
# MF_MSE_PyTorch_Recommender: Epoch 9 of 10. Elapsed time 50.31 sec
# MF_MSE_PyTorch_Recommender: Epoch 10, Batch: [403/403], Samples per second 9642.69
# MF_MSE_PyTorch_Recommender: Epoch 10 of 10. Elapsed time 56.60 sec
# MF_MSE_PyTorch_Recommender: Terminating at epoch 10. Elapsed time 56.61 sec
#
#
#
#  0.00016101209879290973
#
#
#
# MF_MSE_PyTorch_Recommender: URM Detected 461 (5.80 %) cold users.
# MF_MSE_PyTorch_Recommender: URM Detected 5495 (21.15 %) cold items.
# MF_MSE_PyTorch_Recommender: MF_MSE_PyTorch: Using CPU
# MF_MSE_PyTorch_Recommender: Epoch 1, Batch: [403/403], Samples per second 8919.81
# MF_MSE_PyTorch_Recommender: Epoch 1 of 30. Elapsed time 6.80 sec
# MF_MSE_PyTorch_Recommender: Epoch 2, Batch: [403/403], Samples per second 9536.21
# MF_MSE_PyTorch_Recommender: Epoch 2 of 30. Elapsed time 13.15 sec
# MF_MSE_PyTorch_Recommender: Epoch 3, Batch: [403/403], Samples per second 10231.89
# MF_MSE_PyTorch_Recommender: Epoch 3 of 30. Elapsed time 19.08 sec
# MF_MSE_PyTorch_Recommender: Epoch 4, Batch: [403/403], Samples per second 10676.45
# MF_MSE_PyTorch_Recommender: Epoch 4 of 30. Elapsed time 24.77 sec
# MF_MSE_PyTorch_Recommender: Epoch 5, Batch: [403/403], Samples per second 10786.93
# MF_MSE_PyTorch_Recommender: Epoch 5 of 30. Elapsed time 30.39 sec
# MF_MSE_PyTorch_Recommender: Epoch 6, Batch: [403/403], Samples per second 10929.31
# MF_MSE_PyTorch_Recommender: Epoch 6 of 30. Elapsed time 35.94 sec
# MF_MSE_PyTorch_Recommender: Epoch 7, Batch: [403/403], Samples per second 11051.21
# MF_MSE_PyTorch_Recommender: Epoch 7 of 30. Elapsed time 41.43 sec
# MF_MSE_PyTorch_Recommender: Epoch 8, Batch: [403/403], Samples per second 11029.01
# MF_MSE_PyTorch_Recommender: Epoch 8 of 30. Elapsed time 46.93 sec
# MF_MSE_PyTorch_Recommender: Epoch 9, Batch: [403/403], Samples per second 11043.12
# MF_MSE_PyTorch_Recommender: Epoch 9 of 30. Elapsed time 52.43 sec
# MF_MSE_PyTorch_Recommender: Epoch 10, Batch: [403/403], Samples per second 10808.16
# MF_MSE_PyTorch_Recommender: Epoch 10 of 30. Elapsed time 58.04 sec
# MF_MSE_PyTorch_Recommender: Epoch 11, Batch: [403/403], Samples per second 10870.37
# MF_MSE_PyTorch_Recommender: Epoch 11 of 30. Elapsed time 1.06 min
# MF_MSE_PyTorch_Recommender: Epoch 12, Batch: [403/403], Samples per second 11163.44
# MF_MSE_PyTorch_Recommender: Epoch 12 of 30. Elapsed time 1.15 min
# MF_MSE_PyTorch_Recommender: Epoch 13, Batch: [403/403], Samples per second 11118.27
# MF_MSE_PyTorch_Recommender: Epoch 13 of 30. Elapsed time 1.24 min
# MF_MSE_PyTorch_Recommender: Epoch 14, Batch: [403/403], Samples per second 11095.82
# MF_MSE_PyTorch_Recommender: Epoch 14 of 30. Elapsed time 1.33 min
# MF_MSE_PyTorch_Recommender: Epoch 15, Batch: [403/403], Samples per second 10629.52
# MF_MSE_PyTorch_Recommender: Epoch 15 of 30. Elapsed time 1.43 min
# MF_MSE_PyTorch_Recommender: Epoch 16, Batch: [403/403], Samples per second 10383.03
# MF_MSE_PyTorch_Recommender: Epoch 16 of 30. Elapsed time 1.53 min
# MF_MSE_PyTorch_Recommender: Epoch 17, Batch: [403/403], Samples per second 10228.43
# MF_MSE_PyTorch_Recommender: Epoch 17 of 30. Elapsed time 1.62 min
# MF_MSE_PyTorch_Recommender: Epoch 18, Batch: [403/403], Samples per second 9993.39
# MF_MSE_PyTorch_Recommender: Epoch 18 of 30. Elapsed time 1.73 min
# MF_MSE_PyTorch_Recommender: Epoch 19, Batch: [403/403], Samples per second 10697.23
# MF_MSE_PyTorch_Recommender: Epoch 19 of 30. Elapsed time 1.82 min
# MF_MSE_PyTorch_Recommender: Epoch 20, Batch: [403/403], Samples per second 9284.84
# MF_MSE_PyTorch_Recommender: Epoch 20 of 30. Elapsed time 1.93 min
# MF_MSE_PyTorch_Recommender: Epoch 21, Batch: [403/403], Samples per second 10750.49
# MF_MSE_PyTorch_Recommender: Epoch 21 of 30. Elapsed time 2.02 min
# MF_MSE_PyTorch_Recommender: Epoch 22, Batch: [403/403], Samples per second 10970.97
# MF_MSE_PyTorch_Recommender: Epoch 22 of 30. Elapsed time 2.11 min
# MF_MSE_PyTorch_Recommender: Epoch 23, Batch: [403/403], Samples per second 11116.22
# MF_MSE_PyTorch_Recommender: Epoch 23 of 30. Elapsed time 2.21 min
# MF_MSE_PyTorch_Recommender: Epoch 24, Batch: [403/403], Samples per second 10860.58
# MF_MSE_PyTorch_Recommender: Epoch 24 of 30. Elapsed time 2.30 min
# MF_MSE_PyTorch_Recommender: Epoch 25, Batch: [403/403], Samples per second 11041.10
# MF_MSE_PyTorch_Recommender: Epoch 25 of 30. Elapsed time 2.39 min
# MF_MSE_PyTorch_Recommender: Epoch 26, Batch: [403/403], Samples per second 10475.52
# MF_MSE_PyTorch_Recommender: Epoch 26 of 30. Elapsed time 2.49 min
# MF_MSE_PyTorch_Recommender: Epoch 27, Batch: [403/403], Samples per second 9848.49
# MF_MSE_PyTorch_Recommender: Epoch 27 of 30. Elapsed time 2.59 min
# MF_MSE_PyTorch_Recommender: Epoch 28, Batch: [403/403], Samples per second 8779.96
# MF_MSE_PyTorch_Recommender: Epoch 28 of 30. Elapsed time 2.70 min
# MF_MSE_PyTorch_Recommender: Epoch 29, Batch: [403/403], Samples per second 8805.83
# MF_MSE_PyTorch_Recommender: Epoch 29 of 30. Elapsed time 2.82 min
# MF_MSE_PyTorch_Recommender: Epoch 30, Batch: [403/403], Samples per second 8802.66
# MF_MSE_PyTorch_Recommender: Epoch 30 of 30. Elapsed time 2.93 min
# MF_MSE_PyTorch_Recommender: Terminating at epoch 30. Elapsed time 2.93 min
#
#
#
#  0.00010495120987546486
#
#
#
# MF_MSE_PyTorch_Recommender: URM Detected 461 (5.80 %) cold users.
# MF_MSE_PyTorch_Recommender: URM Detected 5495 (21.15 %) cold items.
# MF_MSE_PyTorch_Recommender: MF_MSE_PyTorch: Using CPU
# MF_MSE_PyTorch_Recommender: Epoch 1, Batch:
# MF_MSE_PyTorch_Recommender: Epoch 28, Batch: [403/403], Samples per second 11273.79
# MF_MSE_PyTorch_Recommender: Epoch 28 of 50. Elapsed time 2.73 min
# MF_MSE_PyTorch_Recommender: Epoch 29, Batch: [403/403], Samples per second 11301.19
# MF_MSE_PyTorch_Recommender: Epoch 29 of 50. Elapsed time 2.81 min
# MF_MSE_PyTorch_Recommender: Epoch 30, Batch: [403/403], Samples per second 11231.90
# MF_MSE_PyTorch_Recommender: Epoch 30 of 50. Elapsed time 2.90 min
# MF_MSE_PyTorch_Recommender: Epoch 31, Batch: [403/403], Samples per second 11354.25
# MF_MSE_PyTorch_Recommender: Epoch 31 of 50. Elapsed time 2.99 min
# MF_MSE_PyTorch_Recommender: Epoch 32, Batch: [403/403], Samples per second 11371.34
# MF_MSE_PyTorch_Recommender: Epoch 32 of 50. Elapsed time 3.08 min
# MF_MSE_PyTorch_Recommender: Epoch 33, Batch: [403/403], Samples per second 11356.39
# MF_MSE_PyTorch_Recommender: Epoch 33 of 50. Elapsed time 3.17 min
# MF_MSE_PyTorch_Recommender: Epoch 34, Batch: [403/403], Samples per second 11354.25
# MF_MSE_PyTorch_Recommender: Epoch 34 of 50. Elapsed time 3.26 min
# MF_MSE_PyTorch_Recommender: Epoch 35, Batch: [403/403], Samples per second 11175.81
# MF_MSE_PyTorch_Recommender: Epoch 35 of 50. Elapsed time 3.35 min
# MF_MSE_PyTorch_Recommender: Epoch 36, Batch: [403/403], Samples per second 10712.40
# MF_MSE_PyTorch_Recommender: Epoch 36 of 50. Elapsed time 3.45 min
# MF_MSE_PyTorch_Recommender: Epoch 37, Batch: [403/403], Samples per second 10571.88
# MF_MSE_PyTorch_Recommender: Epoch 37 of 50. Elapsed time 3.54 min
# MF_MSE_PyTorch_Recommender: Epoch 38, Batch: [403/403], Samples per second 12029.85
# MF_MSE_PyTorch_Recommender: Epoch 38 of 50. Elapsed time 3.63 min
# MF_MSE_PyTorch_Recommender: Epoch 39, Batch: [403/403], Samples per second 11885.58
# MF_MSE_PyTorch_Recommender: Epoch 39 of 50. Elapsed time 3.71 min
# MF_MSE_PyTorch_Recommender: Epoch 40, Batch: [403/403], Samples per second 11569.38
# MF_MSE_PyTorch_Recommender: Epoch 40 of 50. Elapsed time 3.80 min
# MF_MSE_PyTorch_Recommender: Epoch 41, Batch: [403/403], Samples per second 11472.77
# MF_MSE_PyTorch_Recommender: Epoch 41 of 50. Elapsed time 3.89 min
# MF_MSE_PyTorch_Recommender: Epoch 42, Batch: [403/403], Samples per second 11468.41
# MF_MSE_PyTorch_Recommender: Epoch 42 of 50. Elapsed time 3.97 min
# MF_MSE_PyTorch_Recommender: Epoch 43, Batch: [403/403], Samples per second 11299.07
# MF_MSE_PyTorch_Recommender: Epoch 43 of 50. Elapsed time 4.06 min
# MF_MSE_PyTorch_Recommender: Epoch 44, Batch: [403/403], Samples per second 10581.14
# MF_MSE_PyTorch_Recommender: Epoch 44 of 50. Elapsed time 4.16 min
# MF_MSE_PyTorch_Recommender: Epoch 45, Batch: [403/403], Samples per second 10882.09
# MF_MSE_PyTorch_Recommender: Epoch 45 of 50. Elapsed time 4.25 min
# MF_MSE_PyTorch_Recommender: Epoch 46, Batch: [403/403], Samples per second 11225.62
# MF_MSE_PyTorch_Recommender: Epoch 46 of 50. Elapsed time 4.34 min
# MF_MSE_PyTorch_Recommender: Epoch 47, Batch: [403/403], Samples per second 9900.11
# MF_MSE_PyTorch_Recommender: Epoch 47 of 50. Elapsed time 4.44 min
# MF_MSE_PyTorch_Recommender: Epoch 48, Batch: [403/403], Samples per second 11138.76
# MF_MSE_PyTorch_Recommender: Epoch 48 of 50. Elapsed time 4.54 min
# MF_MSE_PyTorch_Recommender: Epoch 49, Batch: [403/403], Samples per second 11356.39
# MF_MSE_PyTorch_Recommender: Epoch 49 of 50. Elapsed time 4.62 min
# MF_MSE_PyTorch_Recommender: Epoch 50, Batch: [403/403], Samples per second 11095.82
# MF_MSE_PyTorch_Recommender: Epoch 50 of 50. Elapsed time 4.72 min
# MF_MSE_PyTorch_Recommender: Terminating at epoch 50. Elapsed time 4.72 min
#
#
#
#  9.115445220671283e-05
#
#
#
# MF_MSE_PyTorch_Recommender: URM Detected 461 (5.80 %) cold users.
# MF_MSE_PyTorch_Recommender: URM Detected 5495 (21.15 %) cold items.
# MF_MSE_PyTorch_Recommender: MF_MSE_PyTorch: Using CPU
# MF_MSE_PyTorch_Recommender: Epoch 1, Batch: [403/403], Samples per second 9509.20
# MF_MSE_PyTorch_Recommender: Epoch 1 of 70. Elapsed time 6.37 sec
# C:\Users\Luca Massini\anaconda3\envs\recsys-challenge-Polimi-2020\lib\site-packages\torch\nn\_reduction.py:44: UserWarning: size_average and reduce args will be deprecated, please use reduction='sum' instead.
#   warnings.warn(warning.format(ret))
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-3-d66c203ba4b9> in <module>
#      11                         num_factors=n,
#      12                         learning_rate=0.0001,
# ---> 13                         use_cuda=False)
#      14         map_ = evaluator.evaluate_already_trained(recommender=recommender)[2]
#      15         print("\n\n\n", map_, "\n\n\n")
#
# ~\PycharmProjects\recsys-challenge-Polimi-2020\MF\MF_mse_recommender.py in fit(self, training_set, epochs, batch_size, num_factors, learning_rate, use_cuda)
#      22         self.__learner = MF_MSE_PyTorch(URM_train=self.__urm_train.copy())
#      23         self.__learner.fit(epochs=epochs, batch_size=batch_size, num_factors=num_factors,
# ---> 24                            learning_rate=learning_rate, use_cuda=use_cuda)
#      25         self.__item_factors = sparse.csr_matrix(self.__learner.ITEM_factors)
#      26         self.__user_factors = sparse.csr_matrix(self.__learner.USER_factors)
#
# ~\PycharmProjects\recsys-challenge-Polimi-2020\utils\MatrixFactorization\PyTorch\MF_MSE_PyTorch.py in fit(self, epochs, batch_size, num_factors, learning_rate, use_cuda, **earlystopping_kwargs)
#      69         self._train_with_early_stopping(epochs,
#      70                                         algorithm_name=self.RECOMMENDER_NAME,
# ---> 71                                         **earlystopping_kwargs)
#      72
#      73         self.ITEM_factors = self.ITEM_factors_best.copy()
#
# ~\PycharmProjects\recsys-challenge-Polimi-2020\utils\Incremental_Training_Early_Stopping.py in _train_with_early_stopping(self, epochs_max, epochs_min, validation_every_n, stop_on_validation, validation_metric, lower_validations_allowed, evaluator_object, algorithm_name)
#     171         while epochs_current < epochs_max and not convergence:
#     172
# --> 173             self._run_epoch(epochs_current)
#     174
#     175             # If no validation required, always keep the latest
#
# ~\PycharmProjects\recsys-challenge-Polimi-2020\utils\MatrixFactorization\PyTorch\MF_MSE_PyTorch.py in _run_epoch(self, num_epoch)
#     111             # BACKWARD pass
#     112             self.optimizer.zero_grad()
# --> 113             loss.backward()
#     114             self.optimizer.step()
#
# ~\anaconda3\envs\recsys-challenge-Polimi-2020\lib\site-packages\torch\tensor.py in backward(self, gradient, retain_graph, create_graph)
#     219                 retain_graph=retain_graph,
#     220                 create_graph=create_graph)
# --> 221         torch.autograd.backward(self, gradient, retain_graph, create_graph)
#     222
#     223     def register_hook(self, hook):
#
# ~\anaconda3\envs\recsys-challenge-Polimi-2020\lib\site-packages\torch\autograd\__init__.py in backward(tensors, grad_tensors, retain_graph, create_graph, grad_variables)
#     130     Variable._execution_engine.run_backward(
#     131         tensors, grad_tensors_, retain_graph, create_graph,
# --> 132         allow_unreachable=True)  # allow_unreachable flag
#     133
#     134
#
# KeyboardInterrupt:
